# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, Sequential, optimizers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# !pip install d2l==0.17.0

# %% [markdown]
# #Model 1

# %%
(X_train_val, y_train_val), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
print('train images:', X_train_val.shape)
print('test images:', X_test.shape)

y_train_val = tf.keras.utils.to_categorical(y_train_val, num_classes = 10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes = 10)
print('train labels:', y_train_val.shape)
print('test labels:', y_test.shape)
# Out:
# train images: (50000, 32, 32, 3)
# test images: (10000, 32, 32, 3)
# train labels: (50000, 10)
# test labels: (10000, 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size = 0.1)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((45000, 32, 32, 3), (5000, 32, 32, 3), (45000, 10), (5000, 10))

# %%
def bn_relu_convolution(x, nb_channels, dropout_rate=None, bottleneck=False, weight_decay=1e-4):

    if bottleneck:
        bottleneckWidth = 4
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(nb_channels * bottleneckWidth, (1, 1),
                          kernel_regularizer=tf.keras.regularizers.l2(weight_decay))(x)
        # Dropout
        if dropout_rate:
            x = layers.Dropout(dropout_rate)(x)

    # BN-ReLU-Conv
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(nb_channels, (3, 3), padding='same')(x)

    # Dropout
    if dropout_rate:
        x = layers.Dropout(dropout_rate)(x)

    return x

# %%
def bn_relu_transition(x, nb_channels, dropout_rate=None, compression=1.0, weight_decay=1e-4):

    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu',)(x)
    x = layers.Convolution2D(int(nb_channels * compression), (1, 1), padding='same',
                             kernel_regularizer=tf.keras.regularizers.l2(weight_decay))(x)

    if dropout_rate:
        x = layers.Dropout(dropout_rate)(x)

    x = layers.AveragePooling2D((2, 2), strides=(2, 2))(x)
    return x

# %%
def dense_block(x, num_layers, nb_channels, growth_rate, dropout_rate=None, bottleneck=False,
                    weight_decay=1e-4):

    for i in range(num_layers):
        cb = bn_relu_convolution(x, growth_rate, dropout_rate, 
                                 bottleneck)
        nb_channels += growth_rate
        x = layers.concatenate([cb, x])
    return x, nb_channels

# %%
 def DenseNet(input_shape, dense_blocks, dense_layers, growth_rate, compression, bottleneck, 
                     weight_decay, dropout_rate, num_classes, ):

        img_input = layers.Input(shape=input_shape, name = 'img_input')
        nb_channels = growth_rate


        x = layers.Conv2D(2 * growth_rate, (3, 3), padding='same', strides=(1, 1),name='input_conv', 
                          kernel_regularizer= tf.keras.regularizers.l2(weight_decay))(img_input)


        for block in range(dense_blocks - 1):

            x, nb_channels = dense_block(x, dense_layers[block], nb_channels, growth_rate,
                                     dropout_rate, bottleneck, weight_decay) 

            x = bn_relu_transition(x, nb_channels, dropout_rate, compression, weight_decay)
            nb_channels = int(nb_channels * compression)


        x, nb_channels = dense_block(x, dense_layers[-1], nb_channels,
                                          growth_rate, dropout_rate, weight_decay)

        x = layers.BatchNormalization(name = 'prediction_bn')(x)
        x = layers.Activation('relu',  name = 'prediction_relu', )(x)
        x = layers.GlobalAveragePooling2D( name = 'prediction_pool', )(x)
        prediction = layers.Dense(num_classes, name = 'prediction_dense', activation='softmax')(x)

        return tf.keras.Model(inputs=img_input, outputs=prediction, name='densenet')

# %%
dense_net = DenseNet(input_shape = (32,32,3), dense_blocks = 3, dense_layers = [16]*3,
                     growth_rate = 12, compression = 0.5, num_classes = 10, bottleneck = True, 
                     dropout_rate = None, weight_decay = 1e-5)

# %%
class DenseNet(object):
    
    def __init__(self,input_shape=None, dense_blocks=3, dense_layers=-1, growth_rate=12, num_classes=None,
                 dropout_rate=None, bottleneck=False, compression=1.0, weight_decay=1e-4, depth=40):
        
        # Parameters Check
        if num_classes == None:
            raise Exception(
                'Please define number of classes (e.g. num_classes=10). This is required to create .')

        if compression <= 0.0 or compression > 1.0:
            raise Exception('Compression have to be a value between 0.0 and 1.0.')

        if type(dense_layers) is list:
            if len(dense_layers) != dense_blocks:
                raise AssertionError('Number of dense blocks have to be same length to specified layers')
        elif dense_layers == -1:
            dense_layers = int((depth - 4) / 3)
            if bottleneck:
                dense_layers = int(dense_layers / 2)
            dense_layers = [dense_layers for _ in range(dense_blocks)]
        else:
            dense_layers = [dense_layers for _ in range(dense_blocks)]

        self.dense_blocks = dense_blocks
        self.dense_layers = dense_layers
        self.input_shape = input_shape
        self.growth_rate = growth_rate
        self.weight_decay = weight_decay
        self.dropout_rate = dropout_rate
        self.bottleneck = bottleneck
        self.compression = compression
        self.num_classes = num_classes
        
        
    def build_model(self):
        """
        Build the model
        Returns: tf Keras Model instance
        """
        if self.bottleneck:
            print('Creating DenseNet with Bottlenecks')
        else:
            print('Creating DenseNet without Bottlenecks')
        print('-' * 50)
        print('No.of. dense blocks: %s' % self.dense_blocks)
        print('Layers per dense block: %s' % self.dense_layers)
        print('-'* 50)


        img_input = layers.Input(shape = self.input_shape, name = 'img_input')
        nb_channels = self.growth_rate


        x = layers.Conv2D(2 * self.growth_rate, (3, 3), padding='same', strides=(1, 1),name='input_conv', 
                          kernel_regularizer= tf.keras.regularizers.l2(self.weight_decay))(img_input)


        for block in range(self.dense_blocks - 1):

            x, nb_channels = self.dense_block(x, self.dense_layers[block], nb_channels, self.growth_rate,
                                      self.dropout_rate, self.bottleneck, self.weight_decay) 

            x = self.bn_relu_transition(x, nb_channels, self.dropout_rate, 
                                        self.compression, self.weight_decay) # 1 conv layer
            nb_channels = int(nb_channels * self.compression)


        x, nb_channels = self.dense_block(x, self.dense_layers[-1], nb_channels,
                                          self.growth_rate, self.dropout_rate, self.weight_decay)
        

        x = layers.BatchNormalization(name = 'prediction_bn')(x)
        x = layers.Activation('relu',  name = 'prediction_relu', )(x)
        x = layers.GlobalAveragePooling2D( name = 'prediction_pool', )(x)
        prediction = layers.Dense(self.num_classes, name = 'prediction_dense', activation='softmax')(x)

        return tf.keras.Model(inputs=img_input, outputs=prediction, name='DenseNet')
        
        
    def dense_block(self, x, num_layers, nb_channels, growth_rate, dropout_rate=None, bottleneck=False,
                    weight_decay=1e-4):

        for i in range(num_layers):
            cb = self.bn_relu_convolution(x, growth_rate, dropout_rate, 
                                     bottleneck) # 1 conv if bottleneck = 0 else 2 conv if bottleneck = 1
            nb_channels += growth_rate
            x = layers.concatenate([cb, x])
        return x, nb_channels

        
    def bn_relu_convolution(self, x, nb_channels, dropout_rate=None, bottleneck=False, weight_decay=1e-4):

        if bottleneck:
            bottleneckWidth = 4
            x = layers.BatchNormalization()(x)
            x = layers.Activation('relu')(x)
            x = layers.Conv2D(nb_channels * bottleneckWidth, (1, 1),
                              kernel_regularizer=tf.keras.regularizers.l2(weight_decay))(x)
            # Dropout
            if dropout_rate:
                x = layers.Dropout(dropout_rate)(x)

        # BN-ReLU-Conv
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(nb_channels, (3, 3), padding='same')(x)

        # Dropout
        if dropout_rate:
            x = layers.Dropout(dropout_rate)(x)

        return x

    def bn_relu_transition(self, x, nb_channels, dropout_rate=None, compression=1.0, weight_decay=1e-4):
        """
        Creates a transition layer between dense blocks as transition, which do convolution and pooling.
        Works as downsampling.
        """

        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu',)(x)
        x = layers.Convolution2D(int(nb_channels * compression), (1, 1), padding='same',
                                 kernel_regularizer=tf.keras.regularizers.l2(weight_decay))(x)

        # Adding dropout
        if dropout_rate:
            x = layers.Dropout(dropout_rate)(x)

        x = layers.AveragePooling2D((2, 2), strides=(2, 2))(x)
        return x

# %%
dense_net = DenseNet(input_shape = (32,32,3), dense_blocks = 3, dense_layers = [16]*3,
                     growth_rate = 12, compression = 0.5, num_classes = 10, bottleneck = True, 
                     dropout_rate = None, weight_decay = 1e-6).build_model()
# Out:
# Creating DenseNet with Bottlenecks
# --------------------------------------------------
# No.of. dense blocks: 3
# Layers per dense block: [16, 16, 16]
# --------------------------------------------------

# %%
dense_net.summary()
# Out:
# Model: "DenseNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img_input (InputLayer)         [(None, 32, 32, 3)]  0           []
#
#  input_conv (Conv2D)            (None, 32, 32, 24)   672         ['img_input[0][0]']
#
#  batch_normalization_122 (Batch  (None, 32, 32, 24)  96          ['input_conv[0][0]']
#  Normalization)
#
#  activation_98 (Activation)     (None, 32, 32, 24)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 32, 32, 48)   1200        ['activation_98[0][0]']
#
#  batch_normalization_123 (Batch  (None, 32, 32, 48)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_123[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_99[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 32, 32, 36)   0           ['conv2d_122[0][0]',
#                                                                   'input_conv[0][0]']
#
#  batch_normalization_124 (Batch  (None, 32, 32, 36)  144         ['concatenate_50[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 32, 32, 36)   0           ['batch_normalization_124[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 32, 32, 48)   1776        ['activation_100[0][0]']
#
#  batch_normalization_125 (Batch  (None, 32, 32, 48)  192         ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_125[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_101[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 32, 32, 48)   0           ['conv2d_124[0][0]',
#                                                                   'concatenate_50[0][0]']
#
#  batch_normalization_126 (Batch  (None, 32, 32, 48)  192         ['concatenate_51[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_126[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 32, 32, 48)   2352        ['activation_102[0][0]']
#
#  batch_normalization_127 (Batch  (None, 32, 32, 48)  192         ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_127[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_103[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 32, 32, 60)   0           ['conv2d_126[0][0]',
#                                                                   'concatenate_51[0][0]']
#
#  batch_normalization_128 (Batch  (None, 32, 32, 60)  240         ['concatenate_52[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 32, 32, 60)   0           ['batch_normalization_128[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 32, 32, 48)   2928        ['activation_104[0][0]']
#
#  batch_normalization_129 (Batch  (None, 32, 32, 48)  192         ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_129[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_105[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 32, 32, 72)   0           ['conv2d_128[0][0]',
#                                                                   'concatenate_52[0][0]']
#
#  batch_normalization_130 (Batch  (None, 32, 32, 72)  288         ['concatenate_53[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 32, 32, 72)   0           ['batch_normalization_130[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 32, 32, 48)   3504        ['activation_106[0][0]']
#
#  batch_normalization_131 (Batch  (None, 32, 32, 48)  192         ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_131[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_107[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 32, 32, 84)   0           ['conv2d_130[0][0]',
#                                                                   'concatenate_53[0][0]']
#
#  batch_normalization_132 (Batch  (None, 32, 32, 84)  336         ['concatenate_54[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 32, 32, 84)   0           ['batch_normalization_132[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 32, 32, 48)   4080        ['activation_108[0][0]']
#
#  batch_normalization_133 (Batch  (None, 32, 32, 48)  192         ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_133[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_109[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 32, 32, 96)   0           ['conv2d_132[0][0]',
#                                                                   'concatenate_54[0][0]']
#
#  batch_normalization_134 (Batch  (None, 32, 32, 96)  384         ['concatenate_55[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_134[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 32, 32, 48)   4656        ['activation_110[0][0]']
#
#  batch_normalization_135 (Batch  (None, 32, 32, 48)  192         ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_135[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_111[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 32, 32, 108)  0           ['conv2d_134[0][0]',
#                                                                   'concatenate_55[0][0]']
#
#  batch_normalization_136 (Batch  (None, 32, 32, 108)  432        ['concatenate_56[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 32, 32, 108)  0           ['batch_normalization_136[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 32, 32, 48)   5232        ['activation_112[0][0]']
#
#  batch_normalization_137 (Batch  (None, 32, 32, 48)  192         ['conv2d_135[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_137[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_113[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 32, 32, 120)  0           ['conv2d_136[0][0]',
#                                                                   'concatenate_56[0][0]']
#
#  batch_normalization_138 (Batch  (None, 32, 32, 120)  480        ['concatenate_57[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 32, 32, 120)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 32, 32, 48)   5808        ['activation_114[0][0]']
#
#  batch_normalization_139 (Batch  (None, 32, 32, 48)  192         ['conv2d_137[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_139[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_115[0][0]']
#
#  concatenate_58 (Concatenate)   (None, 32, 32, 132)  0           ['conv2d_138[0][0]',
#                                                                   'concatenate_57[0][0]']
#
#  batch_normalization_140 (Batch  (None, 32, 32, 132)  528        ['concatenate_58[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 32, 32, 132)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 32, 32, 48)   6384        ['activation_116[0][0]']
#
#  batch_normalization_141 (Batch  (None, 32, 32, 48)  192         ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_117 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_141[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_117[0][0]']
#
#  concatenate_59 (Concatenate)   (None, 32, 32, 144)  0           ['conv2d_140[0][0]',
#                                                                   'concatenate_58[0][0]']
#
#  batch_normalization_142 (Batch  (None, 32, 32, 144)  576        ['concatenate_59[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 32, 32, 144)  0           ['batch_normalization_142[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 32, 32, 48)   6960        ['activation_118[0][0]']
#
#  batch_normalization_143 (Batch  (None, 32, 32, 48)  192         ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_143[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_119[0][0]']
#
#  concatenate_60 (Concatenate)   (None, 32, 32, 156)  0           ['conv2d_142[0][0]',
#                                                                   'concatenate_59[0][0]']
#
#  batch_normalization_144 (Batch  (None, 32, 32, 156)  624        ['concatenate_60[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 32, 32, 156)  0           ['batch_normalization_144[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 32, 32, 48)   7536        ['activation_120[0][0]']
#
#  batch_normalization_145 (Batch  (None, 32, 32, 48)  192         ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_145[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_121[0][0]']
#
#  concatenate_61 (Concatenate)   (None, 32, 32, 168)  0           ['conv2d_144[0][0]',
#                                                                   'concatenate_60[0][0]']
#
#  batch_normalization_146 (Batch  (None, 32, 32, 168)  672        ['concatenate_61[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 32, 32, 168)  0           ['batch_normalization_146[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 32, 32, 48)   8112        ['activation_122[0][0]']
#
#  batch_normalization_147 (Batch  (None, 32, 32, 48)  192         ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_147[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_123[0][0]']
#
#  concatenate_62 (Concatenate)   (None, 32, 32, 180)  0           ['conv2d_146[0][0]',
#                                                                   'concatenate_61[0][0]']
#
#  batch_normalization_148 (Batch  (None, 32, 32, 180)  720        ['concatenate_62[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 32, 32, 180)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 32, 32, 48)   8688        ['activation_124[0][0]']
#
#  batch_normalization_149 (Batch  (None, 32, 32, 48)  192         ['conv2d_147[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_149[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_125[0][0]']
#
#  concatenate_63 (Concatenate)   (None, 32, 32, 192)  0           ['conv2d_148[0][0]',
#                                                                   'concatenate_62[0][0]']
#
#  batch_normalization_150 (Batch  (None, 32, 32, 192)  768        ['concatenate_63[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 32, 32, 192)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 32, 32, 48)   9264        ['activation_126[0][0]']
#
#  batch_normalization_151 (Batch  (None, 32, 32, 48)  192         ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_151[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_127[0][0]']
#
#  concatenate_64 (Concatenate)   (None, 32, 32, 204)  0           ['conv2d_150[0][0]',
#                                                                   'concatenate_63[0][0]']
#
#  batch_normalization_152 (Batch  (None, 32, 32, 204)  816        ['concatenate_64[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 32, 32, 204)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 32, 32, 48)   9840        ['activation_128[0][0]']
#
#  batch_normalization_153 (Batch  (None, 32, 32, 48)  192         ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_153[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 32, 32, 12)   5196        ['activation_129[0][0]']
#
#  concatenate_65 (Concatenate)   (None, 32, 32, 216)  0           ['conv2d_152[0][0]',
#                                                                   'concatenate_64[0][0]']
#
#  batch_normalization_154 (Batch  (None, 32, 32, 216)  864        ['concatenate_65[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 32, 32, 216)  0           ['batch_normalization_154[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 32, 32, 102)  22134       ['activation_130[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 16, 16, 102)  0          ['conv2d_153[0][0]']
#  oling2D)
#
#  batch_normalization_155 (Batch  (None, 16, 16, 102)  408        ['average_pooling2d_6[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 16, 16, 102)  0           ['batch_normalization_155[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 16, 16, 48)   4944        ['activation_131[0][0]']
#
#  batch_normalization_156 (Batch  (None, 16, 16, 48)  192         ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_156[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_132[0][0]']
#
#  concatenate_66 (Concatenate)   (None, 16, 16, 114)  0           ['conv2d_155[0][0]',
#                                                                   'average_pooling2d_6[0][0]']
#
#  batch_normalization_157 (Batch  (None, 16, 16, 114)  456        ['concatenate_66[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 16, 16, 114)  0           ['batch_normalization_157[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 16, 16, 48)   5520        ['activation_133[0][0]']
#
#  batch_normalization_158 (Batch  (None, 16, 16, 48)  192         ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_158[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_134[0][0]']
#
#  concatenate_67 (Concatenate)   (None, 16, 16, 126)  0           ['conv2d_157[0][0]',
#                                                                   'concatenate_66[0][0]']
#
#  batch_normalization_159 (Batch  (None, 16, 16, 126)  504        ['concatenate_67[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 16, 16, 126)  0           ['batch_normalization_159[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 16, 16, 48)   6096        ['activation_135[0][0]']
#
#  batch_normalization_160 (Batch  (None, 16, 16, 48)  192         ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_160[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_136[0][0]']
#
#  concatenate_68 (Concatenate)   (None, 16, 16, 138)  0           ['conv2d_159[0][0]',
#                                                                   'concatenate_67[0][0]']
#
#  batch_normalization_161 (Batch  (None, 16, 16, 138)  552        ['concatenate_68[0][0]']
#  Normalization)
#
#  activation_137 (Activation)    (None, 16, 16, 138)  0           ['batch_normalization_161[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 16, 16, 48)   6672        ['activation_137[0][0]']
#
#  batch_normalization_162 (Batch  (None, 16, 16, 48)  192         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_162[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_138[0][0]']
#
#  concatenate_69 (Concatenate)   (None, 16, 16, 150)  0           ['conv2d_161[0][0]',
#                                                                   'concatenate_68[0][0]']
#
#  batch_normalization_163 (Batch  (None, 16, 16, 150)  600        ['concatenate_69[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 16, 16, 150)  0           ['batch_normalization_163[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 16, 16, 48)   7248        ['activation_139[0][0]']
#
#  batch_normalization_164 (Batch  (None, 16, 16, 48)  192         ['conv2d_162[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_164[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_140[0][0]']
#
#  concatenate_70 (Concatenate)   (None, 16, 16, 162)  0           ['conv2d_163[0][0]',
#                                                                   'concatenate_69[0][0]']
#
#  batch_normalization_165 (Batch  (None, 16, 16, 162)  648        ['concatenate_70[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 16, 16, 162)  0           ['batch_normalization_165[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 16, 16, 48)   7824        ['activation_141[0][0]']
#
#  batch_normalization_166 (Batch  (None, 16, 16, 48)  192         ['conv2d_164[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_166[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_142[0][0]']
#
#  concatenate_71 (Concatenate)   (None, 16, 16, 174)  0           ['conv2d_165[0][0]',
#                                                                   'concatenate_70[0][0]']
#
#  batch_normalization_167 (Batch  (None, 16, 16, 174)  696        ['concatenate_71[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 16, 16, 174)  0           ['batch_normalization_167[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 16, 16, 48)   8400        ['activation_143[0][0]']
#
#  batch_normalization_168 (Batch  (None, 16, 16, 48)  192         ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_168[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_144[0][0]']
#
#  concatenate_72 (Concatenate)   (None, 16, 16, 186)  0           ['conv2d_167[0][0]',
#                                                                   'concatenate_71[0][0]']
#
#  batch_normalization_169 (Batch  (None, 16, 16, 186)  744        ['concatenate_72[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 16, 16, 186)  0           ['batch_normalization_169[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 16, 16, 48)   8976        ['activation_145[0][0]']
#
#  batch_normalization_170 (Batch  (None, 16, 16, 48)  192         ['conv2d_168[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_170[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_146[0][0]']
#
#  concatenate_73 (Concatenate)   (None, 16, 16, 198)  0           ['conv2d_169[0][0]',
#                                                                   'concatenate_72[0][0]']
#
#  batch_normalization_171 (Batch  (None, 16, 16, 198)  792        ['concatenate_73[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 16, 16, 198)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 16, 16, 48)   9552        ['activation_147[0][0]']
#
#  batch_normalization_172 (Batch  (None, 16, 16, 48)  192         ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_172[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_148[0][0]']
#
#  concatenate_74 (Concatenate)   (None, 16, 16, 210)  0           ['conv2d_171[0][0]',
#                                                                   'concatenate_73[0][0]']
#
#  batch_normalization_173 (Batch  (None, 16, 16, 210)  840        ['concatenate_74[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 16, 16, 210)  0           ['batch_normalization_173[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 16, 16, 48)   10128       ['activation_149[0][0]']
#
#  batch_normalization_174 (Batch  (None, 16, 16, 48)  192         ['conv2d_172[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_174[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_150[0][0]']
#
#  concatenate_75 (Concatenate)   (None, 16, 16, 222)  0           ['conv2d_173[0][0]',
#                                                                   'concatenate_74[0][0]']
#
#  batch_normalization_175 (Batch  (None, 16, 16, 222)  888        ['concatenate_75[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 16, 16, 222)  0           ['batch_normalization_175[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 16, 16, 48)   10704       ['activation_151[0][0]']
#
#  batch_normalization_176 (Batch  (None, 16, 16, 48)  192         ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_176[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 16, 16, 12)   5196        ['activation_152[0][0]']
#
#  concatenate_76 (Concatenate)   (None, 16, 16, 234)  0           ['conv2d_175[0][0]',
#                                                                   'concatenate_75[0][0]']
#
#  batch_normalization_177 (Batch  (None, 16, 16, 234)  936        ['concatenate_76[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 16, 16, 234)  0           ['batch_normalization_177[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 16, 16, 48)   11280       ['activation_153[0][0]']
#
#  batch_normalization_178 (Batch  (None, 16, 16, 48)  192         ['conv2d_176[0][0]']
# ...
#  conv2d_201 (Conv2D)            (None, 8, 8, 48)     11136       ['activation_178[0][0]']
#
#  batch_normalization_203 (Batch  (None, 8, 8, 48)    192         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_203[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_179[0][0]']
#
#  concatenate_89 (Concatenate)   (None, 8, 8, 243)    0           ['conv2d_202[0][0]',
#                                                                   'concatenate_88[0][0]']
#
#  batch_normalization_204 (Batch  (None, 8, 8, 243)   972         ['concatenate_89[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 8, 8, 243)    0           ['batch_normalization_204[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 8, 8, 48)     11712       ['activation_180[0][0]']
#
#  batch_normalization_205 (Batch  (None, 8, 8, 48)    192         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_205[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_181[0][0]']
#
#  concatenate_90 (Concatenate)   (None, 8, 8, 255)    0           ['conv2d_204[0][0]',
#                                                                   'concatenate_89[0][0]']
#
#  batch_normalization_206 (Batch  (None, 8, 8, 255)   1020        ['concatenate_90[0][0]']
#  Normalization)
#
#  activation_182 (Activation)    (None, 8, 8, 255)    0           ['batch_normalization_206[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 8, 8, 48)     12288       ['activation_182[0][0]']
#
#  batch_normalization_207 (Batch  (None, 8, 8, 48)    192         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_207[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_183[0][0]']
#
#  concatenate_91 (Concatenate)   (None, 8, 8, 267)    0           ['conv2d_206[0][0]',
#                                                                   'concatenate_90[0][0]']
#
#  batch_normalization_208 (Batch  (None, 8, 8, 267)   1068        ['concatenate_91[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 8, 8, 267)    0           ['batch_normalization_208[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 8, 8, 48)     12864       ['activation_184[0][0]']
#
#  batch_normalization_209 (Batch  (None, 8, 8, 48)    192         ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_209[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_185[0][0]']
#
#  concatenate_92 (Concatenate)   (None, 8, 8, 279)    0           ['conv2d_208[0][0]',
#                                                                   'concatenate_91[0][0]']
#
#  batch_normalization_210 (Batch  (None, 8, 8, 279)   1116        ['concatenate_92[0][0]']
#  Normalization)
#
#  activation_186 (Activation)    (None, 8, 8, 279)    0           ['batch_normalization_210[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 8, 8, 48)     13440       ['activation_186[0][0]']
#
#  batch_normalization_211 (Batch  (None, 8, 8, 48)    192         ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_211[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_187[0][0]']
#
#  concatenate_93 (Concatenate)   (None, 8, 8, 291)    0           ['conv2d_210[0][0]',
#                                                                   'concatenate_92[0][0]']
#
#  batch_normalization_212 (Batch  (None, 8, 8, 291)   1164        ['concatenate_93[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 8, 8, 291)    0           ['batch_normalization_212[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 8, 8, 48)     14016       ['activation_188[0][0]']
#
#  batch_normalization_213 (Batch  (None, 8, 8, 48)    192         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_213[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_189[0][0]']
#
#  concatenate_94 (Concatenate)   (None, 8, 8, 303)    0           ['conv2d_212[0][0]',
#                                                                   'concatenate_93[0][0]']
#
#  batch_normalization_214 (Batch  (None, 8, 8, 303)   1212        ['concatenate_94[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 8, 8, 303)    0           ['batch_normalization_214[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 8, 8, 48)     14592       ['activation_190[0][0]']
#
#  batch_normalization_215 (Batch  (None, 8, 8, 48)    192         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_215[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_191[0][0]']
#
#  concatenate_95 (Concatenate)   (None, 8, 8, 315)    0           ['conv2d_214[0][0]',
#                                                                   'concatenate_94[0][0]']
#
#  batch_normalization_216 (Batch  (None, 8, 8, 315)   1260        ['concatenate_95[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 8, 8, 315)    0           ['batch_normalization_216[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 8, 8, 48)     15168       ['activation_192[0][0]']
#
#  batch_normalization_217 (Batch  (None, 8, 8, 48)    192         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_217[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_193[0][0]']
#
#  concatenate_96 (Concatenate)   (None, 8, 8, 327)    0           ['conv2d_216[0][0]',
#                                                                   'concatenate_95[0][0]']
#
#  batch_normalization_218 (Batch  (None, 8, 8, 327)   1308        ['concatenate_96[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 8, 8, 327)    0           ['batch_normalization_218[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 8, 8, 48)     15744       ['activation_194[0][0]']
#
#  batch_normalization_219 (Batch  (None, 8, 8, 48)    192         ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 8, 8, 48)     0           ['batch_normalization_219[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 8, 8, 12)     5196        ['activation_195[0][0]']
#
#  concatenate_97 (Concatenate)   (None, 8, 8, 339)    0           ['conv2d_218[0][0]',
#                                                                   'concatenate_96[0][0]']
#
#  prediction_bn (BatchNormalizat  (None, 8, 8, 339)   1356        ['concatenate_97[0][0]']
#  ion)
#
#  prediction_relu (Activation)   (None, 8, 8, 339)    0           ['prediction_bn[0][0]']
#
#  prediction_pool (GlobalAverage  (None, 339)         0           ['prediction_relu[0][0]']
#  Pooling2D)
#
#  prediction_dense (Dense)       (None, 10)           3400        ['prediction_pool[0][0]']
#
# ==================================================================================================
# Total params: 785,671
# Trainable params: 761,989
# Non-trainable params: 23,682
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import *

# %%
dense_net.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'],)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, 
                                   horizontal_flip=True, vertical_flip=True)
train_datagen.fit(X_train)
train_data = train_datagen.flow(X_train, y_train, batch_size = 200)

# %%
val_datagen = ImageDataGenerator(rescale=1./255)
val_datagen.fit(X_val)
val_data = val_datagen.flow(X_val, y_val, batch_size = 200)

# %%
res_history = dense_net.fit(train_data, epochs = 100,validation_data = (X_val/255.,y_val))
# Out:
# Epoch 1/100
# 225/225 [==============================] - 4400s 20s/step - loss: 1.8231 - accuracy: 0.4510 - val_loss: 3.1122 - val_accuracy: 0.1956
# Epoch 2/100
# 225/225 [==============================] - 4426s 20s/step - loss: 1.4091 - accuracy: 0.5951 - val_loss: 2.6801 - val_accuracy: 0.3290
# Epoch 3/100
# 192/225 [========================>.....] - ETA: 10:40 - loss: 1.2296 - accuracy: 0.6517

# %% [markdown]
# #Model 2

# %%
# !pip install d2l==0.17.0
# Out:
# Installing collected packages: d2l
# Successfully installed d2l-0.17.0

# %%
import tensorflow as tf
from d2l import tensorflow as d2l

class ConvBlock(tf.keras.layers.Layer):
    def __init__(self, num_channels):
        super(ConvBlock, self).__init__()
        self.bn = tf.keras.layers.BatchNormalization()
        self.relu = tf.keras.layers.ReLU()
        self.conv = tf.keras.layers.Conv2D(filters=num_channels,
                                           kernel_size=(3, 3), padding='same')

        self.listLayers = [self.bn, self.relu, self.conv]

    def call(self, x):
        y = x
        for layer in self.listLayers.layers:
            y = layer(y)
        y = tf.keras.layers.concatenate([x, y], axis=-1)
        return y

# %%
class DenseBlock(tf.keras.layers.Layer):
    def __init__(self, num_convs, num_channels):
        super(DenseBlock, self).__init__()
        self.listLayers = []
        for _ in range(num_convs):
            self.listLayers.append(ConvBlock(num_channels))

    def call(self, x):
        for layer in self.listLayers.layers:
            x = layer(x)
        return x

# %%
blk = DenseBlock(2, 10)
X = tf.random.uniform((4, 8, 8, 3))
Y = blk(X)
Y.shape
# Out:
# TensorShape([4, 8, 8, 23])

# %%
class TransitionBlock(tf.keras.layers.Layer):
    def __init__(self, num_channels, **kwargs):
        super(TransitionBlock, self).__init__(**kwargs)
        self.batch_norm = tf.keras.layers.BatchNormalization()
        self.relu = tf.keras.layers.ReLU()
        self.conv = tf.keras.layers.Conv2D(num_channels, kernel_size=1)
        self.avg_pool = tf.keras.layers.AvgPool2D(pool_size=2, strides=2)

    def call(self, x):
        x = self.batch_norm(x)
        x = self.relu(x)
        x = self.conv(x)
        return self.avg_pool(x)

# %%
blk = TransitionBlock(10)
blk(Y).shape
# Out:
# TensorShape([4, 4, 4, 10])

# %%
def block_1():
    return tf.keras.Sequential([
        tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.ReLU(),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')])

# %%
def block_2():
    net = block_1()
    # `num_channels`: the current number of channels
    num_channels, growth_rate = 64, 32
    num_convs_in_dense_blocks = [4, 4, 4, 4]

    for i, num_convs in enumerate(num_convs_in_dense_blocks):
        net.add(DenseBlock(num_convs, growth_rate))
        # This is the number of output channels in the previous dense block
        num_channels += num_convs * growth_rate
        # A transition layer that halves the number of channels is added
        # between the dense blocks
        if i != len(num_convs_in_dense_blocks) - 1:
            num_channels //= 2
            net.add(TransitionBlock(num_channels))
    return net

# %%
def net():
    net = block_2()
    net.add(tf.keras.layers.BatchNormalization())
    net.add(tf.keras.layers.ReLU())
    net.add(tf.keras.layers.GlobalAvgPool2D())
    net.add(tf.keras.layers.Flatten())
    net.add(tf.keras.layers.Dense(10))
    return net

# %%
model = net()

# %%
model.summary
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x7f4b25ff6a10>>

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from keras import datasets

# %%
(X_train,y_train),(X_test,y_test)=datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 258s 163ms/step - loss: 2.4711 - accuracy: 0.1484
# Epoch 2/10
# 1563/1563 [==============================] - 254s 162ms/step - loss: 2.3026 - accuracy: 0.1501
# Epoch 3/10
# 1563/1563 [==============================] - 252s 161ms/step - loss: 2.3026 - accuracy: 0.1486
# Epoch 4/10
# 1563/1563 [==============================] - 252s 162ms/step - loss: 2.3036 - accuracy: 0.1164
# Epoch 5/10
#  318/1563 [=====>........................] - ETA: 3:19 - loss: 2.3026 - accuracy: 0.0892
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-23403be5cfe2> in <module>()
# ----> 1 model.fit(X_train,y_train,epochs=10)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:
